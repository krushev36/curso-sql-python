# %% [markdown]
# # Tarea 01: Fundamentos de Python
#
# ## SQL para Ciencia de Datos usando Databricks
#
# ### Maestria en Ciencia de Datos e Inteligencia de Negocios · Universidad de Antioquia
#
# **Instrucciones generales:**
# - Complete cada ejercicio en las celdas indicadas.
# - No modifique las celdas de enunciado.
# - Ejecute todas las celdas antes de entregar.
# - Entregue el notebook con todas las salidas visibles.

# %% [markdown]
# ---
# ## Ejercicio 1 — Números Primos (Condicionales, ciclos y gráfica)
#
# **Objetivo:** Encontrar todos los números primos menores o iguales a `N` usando la **Criba de Eratóstenes** y visualizar su distribución.
#
# **Pasos:**
# 1. Implemente la Criba de Eratóstenes usando ciclos `for` o `while` y condicionales `if`.
# 2. Obtenga la lista de primos para `N = 200`.
# 3. Calcule la diferencia (gap) entre primos consecutivos.
# 4. Genere **dos gráficas** usando `matplotlib`:
#    - Un gráfico de dispersión que muestre la posición de cada primo en el eje X y su valor en el eje Y.
#    - Un histograma de los gaps entre primos consecutivos.
# 5. Imprima cuántos primos hay menores o iguales a `N`.
#
# > **Pista:** Un número es primo si solo es divisible por 1 y por sí mismo. En la Criba, se parte de una lista donde todos los números se consideran primos y se van descartando los múltiplos de cada primo encontrado.

# %%
import matplotlib.pyplot as plt

# --- Ejercicio 1: complete el código ---

N = 200

# 1. Criba de Eratóstenes
# TODO: cree una lista/arreglo booleano 'es_primo' de tamaño N+1 inicializado en True
# Marque 0 y 1 como no primos
# Itere desde 2 hasta sqrt(N), y para cada primo encontrado marque sus múltiplos como False
# Extraiga la lista de números primos

# 2. Gaps entre primos consecutivos
# TODO: calcule la diferencia entre cada par de primos consecutivos

# 3. Gráfica 1 — dispersión de primos
# TODO

# 4. Gráfica 2 — histograma de gaps
# TODO

# 5. Imprimir cantidad de primos
# TODO

# %% [markdown]
# ---
# ## Ejercicio 2 — Aproximación de sin(x) con series de Taylor (Ciclos, matemáticas y gráfica)
#
# **Objetivo:** Aproximar la función $\sin(x)$ usando su expansión en serie de Taylor y comparar la aproximación con el valor real.
#
# $$\sin(x) = \sum_{n=0}^{\infty} \frac{(-1)^n}{(2n+1)!} x^{2n+1}$$
#
# **Pasos:**
# 1. Implemente una función `sin_taylor(x, terminos)` que calcule la aproximación con el número de términos indicado. Use ciclos y operaciones matemáticas básicas (no use `math.sin` dentro de la función de aproximación).
# 2. Para `x` en el rango $[-2\pi, 2\pi]$ y para `terminos = 1, 3, 5, 10`, calcule la aproximación.
# 3. Genere una gráfica que muestre:
#    - La curva real de `math.sin(x)` o `numpy.sin(x)`.
#    - Las curvas de aproximación para cada número de términos.
#    - Leyenda, título y etiquetas de ejes.
# 4. Imprima el error absoluto máximo para `terminos = 10` en el rango evaluado.
#
# > **Pista:** El factorial puede calcularse con un ciclo acumulativo o usando `math.factorial`. El signo alterna con `(-1)**n`.

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# --- Ejercicio 2: complete el código ---

# 1. Función de aproximación
def sin_taylor(x, terminos):
    """Aproxima sin(x) usando la serie de Taylor con el número de términos dado."""
    # TODO
    pass

# 2. Rango de x
x_vals = np.linspace(-2 * math.pi, 2 * math.pi, 300)

# 3. Gráfica
# TODO: grafique sin(x) real y las aproximaciones para terminos = 1, 3, 5, 10

# 4. Error máximo para terminos = 10
# TODO

# %% [markdown]
# ---
# ## Ejercicio 3 — Conjetura de Collatz (Ciclos, condicionales y gráfica)
#
# **Objetivo:** Explorar la Conjetura de Collatz y visualizar cuántos pasos tarda cada número en llegar a 1.
#
# **Regla de Collatz:** Dado un número entero positivo $n$:
# - Si $n$ es **par**, el siguiente número es $n / 2$.
# - Si $n$ es **impar**, el siguiente número es $3n + 1$.
# - Se repite hasta llegar a 1.
#
# **Pasos:**
# 1. Implemente una función `pasos_collatz(n)` que retorne el número de pasos necesarios para que `n` llegue a 1.
# 2. Para todos los enteros entre 1 y 500, calcule los pasos usando la función anterior.
# 3. Encuentre e imprima qué número en ese rango requiere **más pasos**.
# 4. Genere **dos gráficas**:
#    - Un gráfico de barras con el número de pasos para cada entero del 1 al 50.
#    - Un gráfico de línea que muestre la **secuencia completa** (los valores de la cadena) para el número que más pasos requirió en el rango 1–500.
#
# > **Pista:** Use un ciclo `while` dentro de `pasos_collatz`, con la condición `n != 1`. Tenga cuidado de no entrar en un ciclo infinito si `n` llega a 0.

# %%
import matplotlib.pyplot as plt

# --- Ejercicio 3: complete el código ---

# 1. Función de pasos Collatz
def pasos_collatz(n):
    """Retorna el número de pasos para llegar a 1 desde n."""
    # TODO
    pass

# 2. Calcular pasos para 1..500
# TODO

# 3. Número con más pasos
# TODO

# 4. Gráfica 1 — barras para 1..50
# TODO

# 5. Gráfica 2 — secuencia completa del número con más pasos
# TODO

# %% [markdown]
# ---
# ## Ejercicio 4 — Análisis con Pandas (Dataset, transformaciones y gráficas)
#
# **Objetivo:** Crear un dataset de ventas ficticias, aplicar transformaciones y generar gráficas de análisis.
#
# **Pasos:**
#
# ### 4.1 Creación del dataset
# Cree un DataFrame de pandas con al menos **50 filas** y las siguientes columnas:
# - `fecha`: fechas diarias desde el 2024-01-01 (use `pd.date_range`).
# - `producto`: una de las categorías `['Laptop', 'Celular', 'Tablet', 'Auriculares', 'Cargador']` (asigne aleatoriamente).
# - `region`: una de `['Norte', 'Sur', 'Oriente', 'Occidente']` (asigne aleatoriamente).
# - `unidades`: número entero aleatorio entre 1 y 20.
# - `precio_unitario`: número decimal aleatorio entre 50.0 y 1500.0.
#
# ### 4.2 Transformaciones
# 1. Agregue una columna `ingreso_total = unidades * precio_unitario`.
# 2. Agregue una columna `mes` extraída de la columna `fecha`.
# 3. Filtre las filas donde `ingreso_total > 5000` y muestre cuántas hay.
# 4. Calcule el ingreso total por `producto` y muéstrelo ordenado de mayor a menor.
# 5. Calcule el promedio de `unidades` por `region`.
#
# ### 4.3 Gráficas
# 1. **Gráfica de barras**: ingreso total por producto.
# 2. **Gráfica de torta (pie)**: distribución del ingreso total por región.
# 3. **Gráfica de línea**: ingreso total acumulado por día (ordenado por fecha).
#
# > **Pista:** Use `numpy.random` para generar los datos aleatorios. Para reproducibilidad, fije la semilla con `np.random.seed(42)` al inicio.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

# --- Ejercicio 4: complete el código ---

# 4.1 Creación del dataset
# TODO: cree el DataFrame con las columnas indicadas

# 4.2 Transformaciones
# TODO

# 4.3 Gráficas
# TODO

# %% [markdown]
# ---
# ## Ejercicio 5 — Manipulación de datos con `data.csv` (Parte 1)
#
# > Extraído de: [assignments-python-2024 / assingment](https://github.com/krushev36/assignments-python-2024/tree/main/assingment)
#
# El archivo `data.csv` (incluido junto a este notebook) contiene registros con campos separados por tabulación (`\t`). La **primera columna** es una letra (`A`–`E`) y la **segunda columna** es un número entero.
#
# Realice las siguientes operaciones de forma **independiente** (cada una en su propia celda o bloque de código):
#
# ### 5.1 — Suma de la segunda columna
# Lea el archivo y calcule e imprima la **suma total** de todos los valores de la segunda columna.
#
# **Resultado esperado:**
# ```
# 190
# ```
#
# ### 5.2 — Cantidad de registros por letra
# Cuente cuántos registros hay para cada letra de la primera columna, **ordenados alfabéticamente**. La salida debe tener el formato:
#
# **Resultado esperado:**
# ```
# A,8
# B,7
# C,5
# D,6
# E,14
# ```
#
# ### 5.3 — Suma de la segunda columna por letra
# Calcule la suma de los valores de la segunda columna agrupados por letra de la primera columna, **ordenados alfabéticamente**. La salida debe tener el formato:
#
# **Resultado esperado:**
# ```
# A,37
# B,36
# C,27
# D,23
# E,67
# ```
#
# > **Pista:** Puede leer el archivo con `open()` y procesar línea a línea, o usar `pandas.read_csv` con `sep='\t'` y `header=None`. Para los conteos y sumas agrupadas, puede usar un diccionario o `groupby` de pandas.

# %%
# --- Ejercicio 5: complete el código ---
# Asegúrese de que data.csv esté en la misma carpeta que este notebook.

import pandas as pd

# Leer el archivo
# TODO: cargue data.csv con el separador correcto y sin encabezado
# df = pd.read_csv("data.csv", sep="\t", header=None)

# 5.1 — Suma de la segunda columna
print("=== 5.1 Suma de la segunda columna ===")
# TODO

# 5.2 — Cantidad de registros por letra (ordenado alfabéticamente)
print("\n=== 5.2 Cantidad de registros por letra ===")
# TODO

# 5.3 — Suma de la segunda columna por letra (ordenado alfabéticamente)
print("\n=== 5.3 Suma de la segunda columna por letra ===")
# TODO

# %% [markdown]
# ---
# ## Ejercicio 6 — Manipulación de datos con `data.csv` (Parte 2 — Análisis avanzado)
#
# > Extraído de: [assignments-python-2024 / assingment](https://github.com/krushev36/assignments-python-2024/tree/main/assingment)
#
# Continuando con el mismo archivo `data.csv`, la tercera columna contiene una **fecha** y la cuarta columna contiene una **lista de etiquetas** separadas por comas (ej. `a,f,c`). La quinta columna contiene pares `clave:valor` separados por comas (ej. `ccc:2,ddd:0,aaa:3`).
#
# Realice las siguientes operaciones:
#
# ### 6.1 — Registros por año
# Extraiga el año de la tercera columna y cuente cuántos registros hay por año. Imprima el resultado ordenado por año.
#
# **Resultado esperado:**
# ```
# 1997,9
# 1998,11
# 1999,20
# ```
#
# ### 6.2 — Etiqueta más frecuente
# La cuarta columna contiene listas de etiquetas (letras). Encuentre e imprima cuál es la **etiqueta más frecuente** en todo el dataset (considerando todas las listas de todas las filas).
#
# **Resultado esperado:**
# ```
# f
# ```
#
# ### 6.3 — Suma de valores por clave
# La quinta columna contiene pares `clave:valor`. Para cada clave (ej. `aaa`, `bbb`, `ccc`, etc.), calcule la **suma total de sus valores** en todas las filas donde aparece. Imprima el resultado ordenado alfabéticamente por clave.
#
# **Resultado esperado:**
# ```
# aaa,53
# bbb,82
# ccc,72
# ddd,98
# eee,55
# fff,94
# ggg,61
# hhh,80
# iii,86
# jjj,67
# ```
#
# ### 6.4 — Gráfica
# Genere una gráfica de barras que muestre la suma de valores por clave calculada en el punto 6.3.
#
# > **Pista:** Para procesar la cuarta columna, use `str.split(',')` sobre cada celda. Para la quinta columna, use `str.split(',')` para separar los pares y luego `split(':')` para separar clave y valor. Puede acumular los resultados en un diccionario de Python.

# %%
# --- Ejercicio 6: complete el código ---

import pandas as pd
import matplotlib.pyplot as plt

# Leer el archivo (reutilice la lectura del ejercicio 5 si lo prefiere)
# df = pd.read_csv("data.csv", sep="\t", header=None)
# Asigne nombres de columna para facilitar el trabajo:
# df.columns = ["letra", "numero", "fecha", "etiquetas", "pares"]

# 6.1 — Registros por año
print("=== 6.1 Registros por año ===")
# TODO

# 6.2 — Etiqueta más frecuente (columna 4)
print("\n=== 6.2 Etiqueta más frecuente ===")
# TODO

# 6.3 — Suma de valores por clave (columna 5)
print("\n=== 6.3 Suma de valores por clave ===")
# TODO

# 6.4 — Gráfica de barras: suma de valores por clave
# TODO
